# %%
data = [1,2,3]
if len(data) > 0:
    print("Has data")
if data:
    print("Has data")
empty = []
if not empty:
    print("List is empty")
name = "Alice"
if name:
    print(f"Hello, {name}")
# Out:
# Has data
# Has data
# List is empty
# Hello, Alice
