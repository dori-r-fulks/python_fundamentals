# %%
#Reverse a boolean value
is_raining = True
#if NOT raining, go outside
if not is_raining:
    print("Go for a walk!")
else:
    print("Stay inside.")
# Out:
# Stay inside.

# %%
is_member = True
if not is_member:
    print("Please sign up!")
