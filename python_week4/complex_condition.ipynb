# %%
#College admission logic
gpa = 3.8
test_score = 1350
has_recommendation = True
#Accept if:
if (gpa >= 3.5 and test_score >= 1300) or has_recommendation:
    print("ACCEPTED!")
else:
    print("Not Accepted")
# Out:
# ACCEPTED!
