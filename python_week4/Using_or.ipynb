# %%
#At lease one condition must be True
is_weekend =  True
is_holiday = True

#Can sleep in if weekend or holiday
if is_weekend or is_holiday:
    print("Sleep in!")
else:
    print("Set alarm")
# Out:
# Sleep in!
