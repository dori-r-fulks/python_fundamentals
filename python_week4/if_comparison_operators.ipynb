# %%
#Examples with variables
age = 25
score = 95
name = "Alice"

#Comparisons return True/False
print(age >= 18)
print(score == 100)
print(name == "Bob")

#Use in if statements
if score >= 90:
    print("A grade!") 
if age < 21:
    print("Under 21")
# Out:
# True
# False
# False
# A grade!
