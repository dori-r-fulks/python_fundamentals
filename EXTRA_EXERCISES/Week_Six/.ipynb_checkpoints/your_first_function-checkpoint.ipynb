# %%
#Define the function
def greet():
    print("Hello, World!")
    print("Welcome to functions!")

# %%
#Call the function (use it)
greet()
# Out:
# Hello, World!
# Welcome to functions!

# %%
greet()
# Out:
# Hello, World!
# Welcome to functions!

# %%
greet()
# Out:
# Hello, World!
# Welcome to functions!
