# %%
#Define function with parameter
def greet(name):
    print(f"Hello, {name}!")
    print("Welcome to Python!")

# %%
#Call with different arguments
greet("Valued Customer!")
# Out:
# Hello, Valued Customer!!
# Welcome to Python!

# %%
greet("Professor Lance!")
# Out:
# Hello, Professor Lance!!
# Welcome to Python!

# %%
greet("Dori Fu!")
# Out:
# Hello, Dori Fu!!
# Welcome to Python!
