# %%
#List
student_list = ["Alice", 25, "Engineer"]
name = student_list[0]
age = student_list[1]
job = student_list[2]
print(name)
print(age)
print(job)
# Out:
# Alice
# 25
# Engineer

# %%
#dictionary
student_dict = {"name": "Alice", "age": 25, "job": "Engineer"}
name = student_dict["name"]
print((name), (age), (job))
# Out:
# Alice 25 Engineer
