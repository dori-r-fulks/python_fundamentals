# %%
student = {"name": "Alice", "age": 25}

# %%
#Check before access
if "name" in student:
    print(student["name"])
if "gpa" in student:
    print(student["gpa"])
else:
    print("GPA not recorded")
# Out:
# Alice
# GPA not recorded

# %%
gpa = student.get("gpa", 3.8)
print(f"GPA: {gpa}")
name = student.get("name", "unknown")
print(f"Name: {name}")
# Out:
# GPA: 3.8
# Name: Alice
