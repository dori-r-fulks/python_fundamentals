# %%
student_record = {"name": "Priyanka", "Student_id": 8675309, "age":29, "major": "Data Science", "gpa": 3.5, "courses": ["Python", "Cybersecurity+", "Calculus", "French"]}
print(student_record["name"])
print(student_record["Student_id"])
print(student_record["age"])
print(student_record["major"])
print(student_record["gpa"])
print(student_record["courses"][0])
print(student_record["courses"][1])
print(student_record["courses"][2])
print(student_record["courses"][3])
# Out:
# Priyanka
# 8675309
# 29
# Data Science
# 3.5
# Python
# Cybersecurity+
# Calculus
# French
