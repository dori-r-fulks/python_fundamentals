# %%
student = {"name": "Alice", "age": 25, "major": "CS"}
#Direct access (square brackets)
print(student["name"]) #Alice
print(student["gpa"]) #KeyError! (doesen't exist)
# Out:
# Alice
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       2 #Direct access (square brackets)
#       3 print(student["name"]) #Alice
# ----> 4 print(student["gpa"]) #KeyError! (doesen't exist)
#       5 #Safe access (.get method)
#       6 print(student.get("name")) #Alice
#
# KeyError: 'gpa'

# %%
#Safe access (.get method)
print(student.get("name")) #Alice
print(student.get("gpa"))#None
print(student.get("gpa", 0.0)) #0.0 (default)
# Out:
# Alice
# None
# 0.0
