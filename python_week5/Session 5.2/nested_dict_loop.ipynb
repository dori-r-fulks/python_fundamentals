# %%
#gade book with multiple students
gradebook = {
    "Alice": {"math": 95, "english": 92},
    "Bob": {"math": 87, "english": 90},
    "Carol": {"math": 92, "english": 88}
}

# %%
#Calculate average for each student
for name, grades in gradebook.items():
    total = sum(grades.values())
    avg = total / len(grades)
    print(f"{name}: {avg:.1f}")
# Out:
# Alice: 93.5
# Bob: 88.5
# Carol: 90.0
# Dallas: 94.0
# Erin: 82.0
# Fran'cess: 79.0

# %%
gradebook ["Dallas"] = {"math": 99, "english": 89}

# %%
gradebook ["Erin"] = {"math": 64, "english": 100}

# %%
gradebook["Fran'cess"] = {"math": 78, "english": 80}
