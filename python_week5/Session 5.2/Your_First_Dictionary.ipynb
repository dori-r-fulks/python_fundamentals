# %%
#Create a person dictionary
person = {
    "name": "Alice",
    "age": 25,
    "city": "Boston",
    "job": "Data Scientist"
}

#Access values by key
print(person["name"])
print(person["age"])
print(person["city"])
# Out:
# Alice
# 25
# Boston

# %%
person_list = ["Alice", 25, "Boston", "Data Scientist"]
print(person_list)
# Out:
# ['Alice', 25, 'Boston', 'Data Scientist']
