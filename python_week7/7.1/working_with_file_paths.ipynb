# %%
import os
#Check current directory
print(os.getcwd())
#/home/claude
# Out:
# /Users/panda/python_practice/python_week7

# %%
#List files in directory
print(os.listdir("."))
# Out:
# ['reading_methods_comparison.ipynb', 'working_with_file_paths.ipynb', 'reading_with_"with"_statement.ipynb', 'reading_a_file.ipynb', '.ipynb_checkpoints', 'sample.txt']

# %%
#Check if file exists
if os.path.exists("data.txt"):
    print("File found!")
else:
    print("File not found!")
# Out:
# File not found!

# %%
#Joihn paths (works on any OS!)
filepath = os.path.join("data", "input", "file.txt")
print(filepath)
# Out:
# data/input/file.txt
