# %%
numbers = [10, 25, 30, 15, 40]
total = 0

# %%
for num in numbers:
    total += num
print(f"Total: {total}")
# Out:
# Total: 120

# %%
average = total / len(numbers)
print(f"Average: {average}")
# Out:
# Average: 24.0
