# %%
#Start with empty liist
scores = []

# %%
#Add items one by one
scores.append(95)
print(scores)
scores.append(87)
print(scores)
scores.append(92)
print(scores)
# Out:
# [95, 95]
# [95, 95, 87]
# [95, 95, 87, 92]

# %%
scores.remove(95)

# %%
print(scores)
# Out:
# [95, 87, 92]
