# %%
original = [1, 2, 3, 4, 5, 6,]
reference = original
reference.append(4)
print(original)
print(reference)
# Out:
# [1, 2, 3, 4, 5, 6, 4]
# [1, 2, 3, 4, 5, 6, 4]

# %%
original = [1, 2, 3]
copy = original.copy()
copy.append(4)
print(original)
print(copy)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
original = [1, 2, 3, 4, 5, 6]
reference = original.copy()
reference.append(7)
print(original)
print(reference)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 7]
