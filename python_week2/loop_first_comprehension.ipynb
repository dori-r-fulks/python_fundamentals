# %%
#Square each number (perfect!)
nums = [1, 2, 3, 4, 5]
squares = [n*2 for n in nums]
print(squares)
# Out:
# [2, 4, 6, 8, 10]

# %%
#Make all uppercase (spot on!)
names = ["alice", "bob", "carol"]
upper = [name.upper() for name in names]
print(upper)
# Out:
# ['ALICE', 'BOB', 'CAROL']

# %%
#Capitalize first letter (great use of .capitalization()!)
names = ["alice", "bob", "carol", "carlos"]
capitalized_names = [name.capitalize() for name in names]
print(capitalized_names)
# Out:
# ['Alice', 'Bob', 'Carol', 'Carlos']

# %%
#get string lengths (correct now!)
lengths = [len(name) for name in names]
print(lengths)
# Out:
# [5, 3, 5, 6]

# %%
words = ["hi", "hello", "hey", "goodbye"]
lengths = [len(word) for word in words]
print(lengths)
# Out:
# [2, 5, 3, 7]
