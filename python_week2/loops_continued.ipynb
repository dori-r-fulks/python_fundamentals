# %%
numbers = [5, -3, 8, -1, 12, -7, 15, 0, 20]
for num in numbers:
    if num <= 0:
        continue
        squared = num ** 2
        print(f"{num} squared = {squared}")

# %%
numbers = [5, -3, 8, -1, 12, -7, 15, 0, 20]
for num in numbers:
    if num <= 0:
        continue
    squared = num ** 2
    print(f"{num} squared = {squared}")
# Out:
# 5 squared = 25
# 8 squared = 64
# 12 squared = 144
# 15 squared = 225
# 20 squared = 400
