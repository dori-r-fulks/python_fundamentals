# %%
temperatures = [72, 68, 75, 70, 73]

# %%
#Change first temperature
temperatures[0] = 74
print(temperatures)
# Out:
# [74, 69, 76, 70, 71]

# %%
#Change last temperature
temperatures[-1] = 71
print(temperatures)
# Out:
# [105, 68, 75, 70, 71]

# %%
#change multiple items w/ slicing
temperatures[1:3] = 69, 76
print(temperatures)
# Out:
# [74, 69, 76, 70, 71]
