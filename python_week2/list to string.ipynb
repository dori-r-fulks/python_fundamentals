# %%
words = ["I", "love", "Python"]
sentence = " ".join(words)
print(sentence)
# Out:
# I love Python

# %% [raw]
# words = ['apple', 'banana', 'cherry']
# csv = ','.join(words)
# print(csv)

# %%
words = ['apple', 'banana', 'cherry']
csv = ','.join(words)
print(csv)
# Out:
# apple,banana,cherry

# %%
lines = ['Line 1', 'Line 2', 'Line 3']
text = '\n'.join(lines)
print(text)
# Out:
# Line 1
# Line 2
# Line 3
