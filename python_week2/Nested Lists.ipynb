# %%
grades = [
    [95, 87, 92], #Alice
    [88, 90, 85], #Bob
    [92, 88, 94], #Carol
    [78, 85, 80]  #David
]

# %%
print(grades[0][0])
print(grades[1][2])
# Out:
# 95
# 85

# %%
print(grades[0])
print(grades[1])
print(grades[2])
print(grades[3])
# Out:
# [95, 87, 92]
# [88, 90, 85]
# [92, 88, 94]
# [78, 85, 80]
