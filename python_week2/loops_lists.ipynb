# %%
colors = ["red", "blue", "green", "yellow", "purple", "black"]
sizes = ["extra-small", "small", "schmedium", "medium", "large", "extra-large"]
products = []
for color in colors:
    for size in sizes:
        product = f"{size} {color} shirt"
        products.append(product)
        print(product)
# Out:
# extra-small red shirt
# small red shirt
# schmedium red shirt
# medium red shirt
# large red shirt
# extra-large red shirt
# extra-small blue shirt
# small blue shirt
# schmedium blue shirt
# medium blue shirt
# large blue shirt
# extra-large blue shirt
# extra-small green shirt
# small green shirt
# schmedium green shirt
# medium green shirt
# large green shirt
# extra-large green shirt
# extra-small yellow shirt
# small yellow shirt
# schmedium yellow shirt
# medium yellow shirt
# large yellow shirt
# extra-large yellow shirt
# extra-small purple shirt
# small purple shirt
# schmedium purple shirt
# medium purple shirt
# large purple shirt
# extra-large purple shirt
# extra-small black shirt
# small black shirt
# schmedium black shirt
# medium black shirt
# large black shirt
# extra-large black shirt
