# %%
students = ['Alice', 'Bob', 'Carol', 'David', 'Eve']

# %%
#Get first student
print(students[0])
# Out:
# Alice

# %%
#Get third student
print(students[2])
# Out:
# Carol

# %%
#Get last student (negative index!)
print(students[-1])
# Out:
# Eve

# %%
#Get last student (negative index!)
print(students[-2])
# Out:
# David
