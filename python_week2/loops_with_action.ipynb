# %%
numbers = [1,2,3,4,5]
for num in numbers:
    squared = num ** 2
    print(f"{num} squared is {squared}")
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25

# %%
# Out:
#   Cell In[3], line 1
#     for i in range(5)
#                      ^
# SyntaxError: expected ':'
