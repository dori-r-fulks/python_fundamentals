# %%
students = ["Alice", "Bob", "Carol", "David"]

#with enumerate
for index, name in enumerate(students):
    print(f"Student #{index+99}: {name}")
# Out:
# Student #99: Alice
# Student #100: Bob
# Student #101: Carol
# Student #102: David

# %%
for index, name in enumerate(students, start=1):
    print(f"{index}. {name}")
# Out:
# 1. Alice
# 2. Bob
# 3. Carol
# 4. David
