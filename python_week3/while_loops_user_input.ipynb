# %%
age = 121
while age < 0 or age > 120:
    age = int(input("Enter your age (0-120): "))
    if age < 0 or age > 120:
        print("Invalid! Try again.")
print(f"Valid age: {age}")
# Out:
# Enter your age (0-120):  121
# Invalid! Try again.
# Enter your age (0-120):  120
# Valid age: 120
