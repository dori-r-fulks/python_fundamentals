# %%
#Loop thorugh a list
fruits = ["apple", "banana", "cherry", "orange","plantain","grape","pineapple","lychee","durian"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry
# orange
# plantain
# grape
# pineapple
# lychee
# durian

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
