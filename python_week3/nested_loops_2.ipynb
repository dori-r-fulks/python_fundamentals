# %%
for row in range(8, 12):
    for col in range(8, 12):
        product = row * col
        print(f"{product: 3d}", end=" ")
    print()
# Out:
#  64  72  80  88
#  72  81  90  99
#  80  90  100  110
#  88  99  110  121
