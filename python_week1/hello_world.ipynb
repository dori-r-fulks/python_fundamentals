# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("My name is Dori")
print("I am learning Python")
print("This is exciting!")
# Out:
# My name is Dori
# I am learning Python
# This is exciting!
