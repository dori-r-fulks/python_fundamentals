# %%
#Function with two parameters
def introduce(name, age):
    print(f"My name is {name}")
    print(f"I am {age} years old")

# %%
introduce("Alice", 25)
# Out:
# My name is Alice
# I am 25 years old

# %%
introduce("Bob", 30)
# Out:
# My name is Bob
# I am 30 years old

# %%
introduce("Davis", 96)
# Out:
# My name is Davis
# I am 96 years old

# %%
introduce("Charles", 17)
# Out:
# My name is Charles
# I am 17 years old
