# %%
#Define function with parameter
def greet(name):
    print(f"Hello, {name}!")
    print("Welcome to Python!")

# %%
#Call with different arguments
greet("Alice")
# Out:
# Hello, Alice!
# Welcome to Python!

# %%
greet("Bob")
# Out:
# Hello, Bob!
# Welcome to Python!

# %%
greet("Carol")
# Out:
# Hello, Carol!
# Welcome to Python!
