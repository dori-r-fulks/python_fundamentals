# %%
#Define the function
def greet():
    print("Hello, World!")
    print("Welcome to functions!")

# %%
#Call the function (use it)
greet()
# Out:
# Hello, World!
# Welcome to functions!

# %%
#Call it again
greet()
# Out:
# Hello, World!
# Welcome to functions!
